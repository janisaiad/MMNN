# %%
import jax.numpy as jnp
import matplotlib.pyplot as plt
import seaborn as sns
from jax import random
from scipy.linalg import eigvalsh
from ntk import compute_ntk_2layer_montecarlo_random_field, relu, relu_dot
from tqdm import tqdm

# %% [markdown]
# # Experiment: 2-Layer NTK Analysis with ReLU Activation
#
# We analyze the Neural Tangent Kernel for a 2-layer network with ReLU activation:
# 1. Compute NTK matrices for different (sigma_A, sigma_c) configurations
# 2. Plot the resulting matrices and their eigenvalue spectra
# 3. Analyze projection onto a*I + b*J subspace

# %%
# we set up base parameters
key = random.PRNGKey(42)
input_dim = 2  # we fix input dimension
n_samples = 4  # we fix sample size
ranks_to_test = range(2,100) # we test different ranks[0] values
beta = 1.0  # we fix random bias scaling
n_mc_samples = 300  # we fix number of Monte Carlo samples

# we test different sigma_A and sigma_c combinations
sigma_As = [jnp.sqrt(2)]
sigma_cs = [1.0]

# we generate test data
X = random.normal(key, (n_samples, input_dim))
X = X / jnp.linalg.norm(X, axis=1, keepdims=True)  # we normalize to unit sphere

# we store l2 losses and coordinates for each rank
l2_losses = {rank: [] for rank in ranks_to_test}
i_coords = {rank: [] for rank in ranks_to_test}  # we store I coordinates
j_coords = {rank: [] for rank in ranks_to_test}  # we store J coordinates

def compute_projection_matrices(n):
    """we compute normalized I and J matrices for projection"""
    I = jnp.eye(n)
    J = jnp.ones((n,n)) - jnp.eye(n)
    I_norm = jnp.linalg.norm(I, 'fro')
    J_norm = jnp.linalg.norm(J, 'fro')
    return I/I_norm, J/J_norm

def project_onto_IJ_space(K, I_norm, J_norm):
    """we project matrix K onto span{I,J}"""
    K_norm = jnp.linalg.norm(K, 'fro')
    K = K/K_norm  # we normalize K
    
    # we compute coefficients
    a = jnp.sum(K * I_norm)
    b = jnp.sum(K * J_norm)
    
    # we compute projection
    proj = a*I_norm + b*J_norm
    
    # we compute L2 loss
    l2_loss = jnp.linalg.norm(K - proj, 'fro')
    return l2_loss, a, b

# we compute and plot NTK matrices for each configuration
n_samples_ntk = 50  # we fix number of samples for NTK distribution analysis

with tqdm(total=len(ranks_to_test)*len(sigma_As)*len(sigma_cs), desc="Overall Progress") as pbar:
    for rank in ranks_to_test:
        print(f"\nTesting rank[0]={rank}")
        
        I_norm, J_norm = compute_projection_matrices(n_samples)
        
        for sigma_A in sigma_As:
            for sigma_c in sigma_cs:
                try:
                    # we store NTK values for distribution analysis
                    ntk_samples = []
                    l2_loss_samples = []
                    i_coord_samples = []
                    j_coord_samples = []
                    
                    # we compute multiple NTK samples
                    for i in range(n_samples_ntk): # we have to care about the key wtf
                        ntk = compute_ntk_2layer_montecarlo_random_field(
                            X,
                            ranks=[rank,1],
                            sigma_A=sigma_A,
                            sigma_c=sigma_c,
                            beta=beta,
                            activation_fn=relu,
                            activation_dot_fn=relu_dot,
                            key=random.split(key)[1]+i,  # we use different keys for each sample
                            n_samples=n_mc_samples
                        )
                        ntk_samples.append(ntk)
                        
                        # we compute L2 loss and coordinates from projection
                        l2_loss, i_coord, j_coord = project_onto_IJ_space(ntk, I_norm, J_norm)
                        l2_loss_samples.append(l2_loss)
                        i_coord_samples.append(i_coord)
                        j_coord_samples.append(j_coord)
                    
                    # we convert to arrays for statistics
                    ntk_samples = jnp.array(ntk_samples) # this is a 3D array of shape (n_samples_ntk, n_samples, n_samples)
                    l2_loss_samples = jnp.array(l2_loss_samples)
                    i_coord_samples = jnp.array(i_coord_samples)
                    j_coord_samples = jnp.array(j_coord_samples)
                    
                    # we store mean values
                    l2_losses[rank].append(jnp.mean(l2_loss_samples))
                    i_coords[rank].append(jnp.mean(i_coord_samples))
                    j_coords[rank].append(jnp.mean(j_coord_samples))
                    
                    # we plot NTK distribution for a few selected entries
                    plt.figure(figsize=(15, 5))
                    for idx, (i, j) in enumerate([(0,0), (0,1), (1,1)]):  # we select a few matrix entries
                        plt.subplot(1, 3, idx+1)
                        entry_samples = ntk_samples[:, i, j]
                    
                        plt.hist(entry_samples, bins='auto', density=True)
                        plt.axvline(jnp.mean(entry_samples), color='r', linestyle='--', 
                                  label=f'Mean: {jnp.mean(entry_samples):.3f}\nStd: {jnp.std(entry_samples):.3f}')
                        plt.title(f'NTK Distribution at ({i},{j})')
                        plt.legend()
                    plt.suptitle(f'NTK Entry Distributions (rank={rank}, σA={sigma_A}, σc={sigma_c})')
                    plt.tight_layout()
                    plt.show()
                    
                    # we plot mean NTK matrix
                    mean_ntk = jnp.mean(ntk_samples, axis=0)
                    plt.figure(figsize=(8, 6))
                    sns.heatmap(mean_ntk, cmap='viridis', annot=True, fmt='.3f')
                    plt.title(f'Mean NTK Matrix (rank={rank}, σA={sigma_A}, σc={sigma_c})')
                    plt.tight_layout()
                    plt.show()
                    
                    # we plot eigenvalue distribution of individual samples
                    eigenvals = jnp.array([jnp.linalg.eigvalsh(ntk) for ntk in ntk_samples])
                    mean_eigenvals = jnp.mean(eigenvals, axis=0)
                    std_eigenvals = jnp.std(eigenvals, axis=0)
                    
                    plt.figure(figsize=(8, 6))
                    plt.errorbar(range(1, len(mean_eigenvals) + 1), 
                               jnp.sort(mean_eigenvals)[::-1],
                               yerr=jnp.sort(std_eigenvals)[::-1],
                               fmt='o-', capsize=5)
                    plt.title(f'Sample-wise Eigenvalue Spectrum with Std Dev (rank={rank}, σA={sigma_A}, σc={sigma_c})')
                    plt.xlabel('Index')
                    plt.ylabel('Eigenvalue')
                    plt.grid(True)
                    plt.show()
                    
                    # we plot eigenvalues of mean NTK
                    mean_ntk_eigenvals = jnp.linalg.eigvalsh(mean_ntk)
                    plt.figure(figsize=(8, 6))
                    plt.plot(range(1, len(mean_ntk_eigenvals) + 1), 
                            jnp.sort(mean_ntk_eigenvals)[::-1],
                            'o-')
                    plt.title(f'Mean NTK Eigenvalue Spectrum (rank={rank}, σA={sigma_A}, σc={sigma_c})')
                    plt.xlabel('Index')
                    plt.ylabel('Eigenvalue')
                    plt.grid(True)
                    plt.show()
                    
                    # we compute and plot L2 loss for mean NTK
                    mean_ntk_l2_loss, mean_ntk_i_coord, mean_ntk_j_coord = project_onto_IJ_space(mean_ntk, I_norm, J_norm)
                    
                    print(f"Mean min eigenvalue: {jnp.mean(jnp.min(eigenvals, axis=1)):.3f} ± {jnp.std(jnp.min(eigenvals, axis=1)):.3f}")
                    print(f"Mean max eigenvalue: {jnp.mean(jnp.max(eigenvals, axis=1)):.3f} ± {jnp.std(jnp.max(eigenvals, axis=1)):.3f}")
                    print(f"Mean condition number: {jnp.mean(jnp.max(eigenvals, axis=1)/jnp.min(eigenvals, axis=1)):.3f}")
                    print(f"Mean L2 loss: {jnp.mean(l2_loss_samples):.3f} ± {jnp.std(l2_loss_samples):.3f}")
                    print(f"Mean NTK L2 loss: {mean_ntk_l2_loss:.3f}")
                    print(f"Mean I coordinate: {jnp.mean(i_coord_samples):.3f} ± {jnp.std(i_coord_samples):.3f}")
                    print(f"Mean NTK I coordinate: {mean_ntk_i_coord:.3f}")
                    print(f"Mean J coordinate: {jnp.mean(j_coord_samples):.3f} ± {jnp.std(j_coord_samples):.3f}")
                    print(f"Mean NTK J coordinate: {mean_ntk_j_coord:.3f}")
                    
                except Exception as e:
                    print(f"Error at rank={rank}, σA={sigma_A}, σc={sigma_c}: {str(e)}")
                    continue
                
                pbar.update(1)
# Out:
# Overall Progress:   0%|          | 0/98 [00:00<?, ?it/s]
# Testing rank[0]=2
# Overall Progress:   1%|          | 1/98 [00:24<40:04, 24.79s/it]
# Mean min eigenvalue: 2.476 ± 1.823
# Mean max eigenvalue: 15.249 ± 2.704
# Mean condition number: 11.365
# Mean L2 loss: 0.146 ± 0.074
# Mean NTK L2 loss: 0.016
# Mean I coordinate: 0.791 ± 0.080
# Mean NTK I coordinate: 0.811
# Mean J coordinate: 0.577 ± 0.097
# Mean NTK J coordinate: 0.585
#
# Testing rank[0]=3
# Overall Progress:   2%|▏         | 2/98 [00:30<22:03, 13.79s/it]
# Mean min eigenvalue: 1.928 ± 0.983
# Mean max eigenvalue: 12.112 ± 1.575
# Mean condition number: -9.761
# Mean L2 loss: 0.112 ± 0.056
# Mean NTK L2 loss: 0.014
# Mean I coordinate: 0.772 ± 0.053
# Mean NTK I coordinate: 0.782
# Mean J coordinate: 0.618 ± 0.062
# Mean NTK J coordinate: 0.623
#
# Testing rank[0]=4
# Overall Progress:   3%|▎         | 3/98 [00:36<15:52, 10.02s/it]
# Mean min eigenvalue: 1.635 ± 0.734
# Mean max eigenvalue: 10.528 ± 1.207
# Mean condition number: 7.122
# Mean L2 loss: 0.082 ± 0.040
# Mean NTK L2 loss: 0.010
# Mean I coordinate: 0.750 ± 0.049
# Mean NTK I coordinate: 0.758
# Mean J coordinate: 0.651 ± 0.056
# Mean NTK J coordinate: 0.652
#
# Testing rank[0]=5
# Overall Progress:   4%|▍         | 4/98 [00:41<12:55,  8.25s/it]
# Mean min eigenvalue: 1.321 ± 0.595
# Mean max eigenvalue: 9.772 ± 0.928
# Mean condition number: 20.092
# Mean L2 loss: 0.075 ± 0.035
# Mean NTK L2 loss: 0.010
# Mean I coordinate: 0.724 ± 0.050
# Mean NTK I coordinate: 0.730
# Mean J coordinate: 0.681 ± 0.052
# Mean NTK J coordinate: 0.683
#
# Testing rank[0]=6
# Overall Progress:   5%|▌         | 5/98 [00:51<13:14,  8.54s/it]
# Mean min eigenvalue: 1.174 ± 0.419
# Mean max eigenvalue: 9.124 ± 0.812
# Mean condition number: 8.741
# Mean L2 loss: 0.063 ± 0.029
# Mean NTK L2 loss: 0.010
# Mean I coordinate: 0.710 ± 0.040
# Mean NTK I coordinate: 0.715
# Mean J coordinate: 0.698 ± 0.040
# Mean NTK J coordinate: 0.699
#
# Testing rank[0]=7
# Overall Progress:   6%|▌         | 6/98 [00:56<11:30,  7.51s/it]
# Mean min eigenvalue: 1.036 ± 0.396
# Mean max eigenvalue: 8.743 ± 0.726
# Mean condition number: 10.090
# Mean L2 loss: 0.056 ± 0.021
# Mean NTK L2 loss: 0.008
# Mean I coordinate: 0.694 ± 0.043
# Mean NTK I coordinate: 0.699
# Mean J coordinate: 0.715 ± 0.042
# Mean NTK J coordinate: 0.715
#
# Testing rank[0]=8
# Overall Progress:   7%|▋         | 7/98 [01:02<10:33,  6.96s/it]
# Mean min eigenvalue: 0.919 ± 0.373
# Mean max eigenvalue: 8.434 ± 0.669
# Mean condition number: 11.857
# Mean L2 loss: 0.055 ± 0.024
# Mean NTK L2 loss: 0.008
# Mean I coordinate: 0.681 ± 0.043
# Mean NTK I coordinate: 0.686
# Mean J coordinate: 0.727 ± 0.040
# Mean NTK J coordinate: 0.728
#
# Testing rank[0]=9
# Overall Progress:   8%|▊         | 8/98 [01:08<09:50,  6.56s/it]
# Mean min eigenvalue: 0.852 ± 0.332
# Mean max eigenvalue: 8.161 ± 0.593
# Mean condition number: 11.754
# Mean L2 loss: 0.048 ± 0.020
# Mean NTK L2 loss: 0.007
# Mean I coordinate: 0.673 ± 0.040
# Mean NTK I coordinate: 0.677
# Mean J coordinate: 0.736 ± 0.036
# Mean NTK J coordinate: 0.736
#
# Testing rank[0]=10
# Overall Progress:   9%|▉         | 9/98 [01:14<09:37,  6.49s/it]
# Mean min eigenvalue: 0.778 ± 0.338
# Mean max eigenvalue: 7.973 ± 0.556
# Mean condition number: 13.057
# Mean L2 loss: 0.047 ± 0.024
# Mean NTK L2 loss: 0.007
# Mean I coordinate: 0.663 ± 0.040
# Mean NTK I coordinate: 0.667
# Mean J coordinate: 0.744 ± 0.035
# Mean NTK J coordinate: 0.745
#
# Testing rank[0]=11
# Overall Progress:  10%|█         | 10/98 [01:20<09:17,  6.33s/it]
# Mean min eigenvalue: 0.732 ± 0.309
# Mean max eigenvalue: 7.801 ± 0.537
# Mean condition number: 15.463
# Mean L2 loss: 0.043 ± 0.016
# Mean NTK L2 loss: 0.009
# Mean I coordinate: 0.658 ± 0.040
# Mean NTK I coordinate: 0.661
# Mean J coordinate: 0.750 ± 0.035
# Mean NTK J coordinate: 0.750
#
# Testing rank[0]=12
# Overall Progress:  11%|█         | 11/98 [01:30<10:43,  7.39s/it]
# Mean min eigenvalue: 0.607 ± 0.281
# Mean max eigenvalue: 7.630 ± 0.517
# Mean condition number: 15.707
# Mean L2 loss: 0.045 ± 0.025
# Mean NTK L2 loss: 0.006
# Mean I coordinate: 0.642 ± 0.033
# Mean NTK I coordinate: 0.645
# Mean J coordinate: 0.764 ± 0.027
# Mean NTK J coordinate: 0.764
#
# Testing rank[0]=13
# Overall Progress:  12%|█▏        | 12/98 [01:36<10:07,  7.07s/it]
# Mean min eigenvalue: 0.586 ± 0.269
# Mean max eigenvalue: 7.544 ± 0.491
# Mean condition number: 20.198
# Mean L2 loss: 0.041 ± 0.022
# Mean NTK L2 loss: 0.007
# Mean I coordinate: 0.637 ± 0.034
# Mean NTK I coordinate: 0.639
# Mean J coordinate: 0.769 ± 0.028
# Mean NTK J coordinate: 0.769
#
# Testing rank[0]=14
# Overall Progress:  13%|█▎        | 13/98 [01:42<09:31,  6.72s/it]
# Mean min eigenvalue: 0.543 ± 0.244
# Mean max eigenvalue: 7.427 ± 0.491
# Mean condition number: 16.790
# Mean L2 loss: 0.038 ± 0.022
# Mean NTK L2 loss: 0.007
# Mean I coordinate: 0.630 ± 0.031
# Mean NTK I coordinate: 0.633
# Mean J coordinate: 0.774 ± 0.025
# Mean NTK J coordinate: 0.774
#
# Testing rank[0]=15
# Overall Progress:  14%|█▍        | 14/98 [01:48<09:04,  6.48s/it]
# Mean min eigenvalue: 0.518 ± 0.215
# Mean max eigenvalue: 7.309 ± 0.464
# Mean condition number: 17.628
# Mean L2 loss: 0.035 ± 0.017
# Mean NTK L2 loss: 0.006
# Mean I coordinate: 0.624 ± 0.030
# Mean NTK I coordinate: 0.626
# Mean J coordinate: 0.780 ± 0.024
# Mean NTK J coordinate: 0.780
#
# Testing rank[0]=16
# Overall Progress:  15%|█▌        | 15/98 [01:54<08:43,  6.31s/it]
# Mean min eigenvalue: 0.488 ± 0.198
# Mean max eigenvalue: 7.247 ± 0.454
# Mean condition number: 13.530
# Mean L2 loss: 0.035 ± 0.018
# Mean NTK L2 loss: 0.006
# Mean I coordinate: 0.620 ± 0.028
# Mean NTK I coordinate: 0.622
# Mean J coordinate: 0.782 ± 0.022
# Mean NTK J coordinate: 0.783
#
# Testing rank[0]=17
# Overall Progress:  15%|█▌        | 15/98 [01:56<10:45,  7.77s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 66
#      64 # we compute multiple NTK samples
#      65 for i in range(n_samples_ntk): # we have to care about the key wtf
# ---> 66     ntk = compute_ntk_2layer_montecarlo_random_field(
#      67         X,
#      68         ranks=[rank,1],
#      69         sigma_A=sigma_A,
#      70         sigma_c=sigma_c,
#      71         beta=beta,
#      72         activation_fn=relu,
#      73         activation_dot_fn=relu_dot,
#      74         key=random.split(key)[1]+i,  # we use different keys for each sample
#      75         n_samples=n_mc_samples
#      76     )
#      77     ntk_samples.append(ntk)
#      79     # we compute L2 loss and coordinates from projection
#
# File ~/STG3A/MMNN/model/ntk/ntk_infinite.py:345, in compute_ntk_2layer_montecarlo_random_field(X, ranks, sigma_A, sigma_c, beta, activation_fn, activation_dot_fn, key, n_samples)
#     342             h_xp = h_x+0.0
#     344         K1 = K1.at[i,j].set(jnp.mean(activation_fn(jnp.mean(jnp.multiply(h_x,w),axis=1) + beta*b)*activation_fn(jnp.mean(jnp.multiply(h_xp,w),axis=1) + beta*b)))
# --> 345         K2 = K2.at[i,j].set(jnp.mean(activation_dot_fn(jnp.mean(jnp.multiply(h_x,w),axis=1) + beta*b) * jnp.mean(jnp.multiply(h_x,w),axis=1)*jnp.mean(jnp.multiply(w,w),axis=1)))
#     347 K1 = K1 + K1.T - jnp.diag(jnp.diag(K1))
#     348 K2 = K2 + K2.T - jnp.diag(jnp.diag(K2))
#
# File ~/STG3A/MMNN/.venv/lib/python3.12/site-packages/jax/_src/numpy/array_methods.py:798, in _IndexUpdateRef.set(self, values, indices_are_sorted, unique_indices, mode)
#     789 def set(self, values, *, indices_are_sorted=False, unique_indices=False,
#     790         mode=None):
#     791   """Pure equivalent of ``x[idx] = y``.
#     792
#     793   Returns the value of ``x`` that would result from the NumPy-style
#    (...)    796   See :mod:`jax.ops` for details.
#     797   """
# --> 798   return scatter._scatter_update(self.array, self.index, values, lax.scatter,
#     799                                  indices_are_sorted=indices_are_sorted,
#     800                                  unique_indices=unique_indices, mode=mode)
#
# File ~/STG3A/MMNN/.venv/lib/python3.12/site-packages/jax/_src/ops/scatter.py:77, in _scatter_update(x, idx, y, scatter_op, indices_are_sorted, unique_indices, mode, normalize_indices)
#      74 # XLA gathers and scatters are very similar in structure; the scatter logic
#      75 # is more or less a transpose of the gather equivalent.
#      76 treedef, static_idx, dynamic_idx = indexing.split_index_for_jit(idx, x.shape)
# ---> 77 return _scatter_impl(x, y, scatter_op, treedef, static_idx, dynamic_idx,
#      78                      indices_are_sorted, unique_indices, mode,
#      79                      normalize_indices)
#
# File ~/STG3A/MMNN/.venv/lib/python3.12/site-packages/jax/_src/ops/scatter.py:101, in _scatter_impl(x, y, scatter_op, treedef, static_idx, dynamic_idx, indices_are_sorted, unique_indices, mode, normalize_indices)
#      93   warnings.warn(
#      94     "scatter inputs have incompatible types: cannot safely cast value "
#      95     f"from dtype={lax.dtype(y)} to dtype={lax.dtype(x)} with "
#      96     f"jax_numpy_dtype_promotion={config.numpy_dtype_promotion.value!r}. "
#      97     "In future JAX releases this will result in an error.",
#      98     FutureWarning)
#     100 idx = indexing.merge_static_and_dynamic_indices(treedef, static_idx, dynamic_idx)
# --> 101 indexer = indexing.index_to_gather(np.shape(x), idx,
#     102                                    normalize_indices=normalize_indices)
#     104 # Avoid calling scatter if the slice shape is empty, both as a fast path and
#     105 # to handle cases like zeros(0)[array([], int32)].
#     106 if core.is_empty_shape(indexer.slice_shape):
#
# File ~/STG3A/MMNN/.venv/lib/python3.12/site-packages/jax/_src/numpy/indexing.py:892, in index_to_gather(x_shape, idx, normalize_indices)
#     890   raise IndexError(f"index is out of bounds for axis {x_axis} with size 0")
#     891 i = _normalize_index(i, x_shape[x_axis]) if normalize_indices else i
# --> 892 i_converted = lax.convert_element_type(i, index_dtype)
#     893 gather_indices.append((i_converted, len(gather_indices_shape)))
#     894 collapsed_slice_dims.append(x_axis)
#
# File ~/STG3A/MMNN/.venv/lib/python3.12/site-packages/jax/_src/lax/lax.py:1542, in convert_element_type(operand, new_dtype)
#    1509 @export
#    1510 def convert_element_type(operand: ArrayLike,
#    1511                          new_dtype: DTypeLike | dtypes.ExtendedDType) -> Array:
#    1512   """Elementwise cast.
#    1513
#    1514   This function lowers directly to the `stablehlo.convert`_ operation, which
#    (...)   1540   .. _x64 mode: https://docs.jax.dev/en/latest/notebooks/Common_Gotchas_in_JAX.html#double-64bit-precision
#    1541   """
# -> 1542   return _convert_element_type(operand, new_dtype, weak_type=False)
#
# File ~/STG3A/MMNN/.venv/lib/python3.12/site-packages/jax/_src/lax/lax.py:1614, in _convert_element_type(operand, new_dtype, weak_type, sharding, warn_on_complex_to_real_cast)
#    1612   return operand
#    1613 else:
# -> 1614   return convert_element_type_p.bind(
#    1615       operand, new_dtype=new_dtype, weak_type=bool(weak_type),
#    1616       sharding=sharding)
#
# File ~/STG3A/MMNN/.venv/lib/python3.12/site-packages/jax/_src/core.py:502, in Primitive.bind(self, *args, **params)
#     500 def bind(self, *args, **params):
#     501   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 502   return self._true_bind(*args, **params)
#
# File ~/STG3A/MMNN/.venv/lib/python3.12/site-packages/jax/_src/core.py:520, in Primitive._true_bind(self, *args, **params)
#     518 trace_ctx.set_trace(eval_trace)
#     519 try:
# --> 520   return self.bind_with_trace(prev_trace, args, params)
#     521 finally:
#     522   trace_ctx.set_trace(prev_trace)
#
# File ~/STG3A/MMNN/.venv/lib/python3.12/site-packages/jax/_src/lax/lax.py:4701, in _convert_element_type_bind_with_trace(trace, args, params)
#    4699 def _convert_element_type_bind_with_trace(trace, args, params):
#    4700   sharding = params['sharding']
# -> 4701   operand = core.Primitive.bind_with_trace(convert_element_type_p, trace, args, params)
#    4702   if sharding is not None and sharding._is_concrete:
#    4703     with core.set_current_trace(trace):
#
# File ~/STG3A/MMNN/.venv/lib/python3.12/site-packages/jax/_src/core.py:525, in Primitive.bind_with_trace(self, trace, args, params)
#     524 def bind_with_trace(self, trace, args, params):
# --> 525   return trace.process_primitive(self, args, params)
#
# File ~/STG3A/MMNN/.venv/lib/python3.12/site-packages/jax/_src/core.py:1029, in EvalTrace.process_primitive(self, primitive, args, params)
#    1027       return primitive.bind_with_trace(arg._trace, args, params)
#    1028 check_eval_args(args)
# -> 1029 return primitive.impl(*args, **params)
#
# KeyboardInterrupt:

# %%
# we compute mean losses and fit power law
mean_losses = [jnp.mean(jnp.array(l2_losses[rank])) for rank in ranks_to_test]
mean_ntk_losses = [mean_ntk_l2_loss for rank in ranks_to_test]  # we add mean NTK losses
ranks_array = jnp.array(list(ranks_to_test))
log_ranks = jnp.log(ranks_array)
log_losses = jnp.log(jnp.array(mean_losses))

# we fit power law using linear regression in log space
A = jnp.vstack([log_ranks, jnp.ones_like(log_ranks)]).T
m, b = jnp.linalg.lstsq(A, log_losses, rcond=None)[0]
power_law = jnp.exp(b) * ranks_array**m

# we plot L2 loss vs rank in log-log space
plt.figure(figsize=(10, 6))
plt.loglog(ranks_array, mean_losses, 'o', label='Sample Mean Loss')
plt.loglog(ranks_array, mean_ntk_losses, 's', label='Mean NTK Loss')  # we add mean NTK plot
plt.loglog(ranks_array, power_law, 'r-', label=f'Fit: y ∝ x^{m:.2f}')
plt.title('L2 Loss vs Rank (Log-Log)')
plt.xlabel('Rank (log scale)')
plt.ylabel('L2 Loss (log scale)')
plt.legend()
plt.grid(True)
plt.show()

# we plot I and J coordinates vs rank
plt.figure(figsize=(12, 6))
mean_i_coords = [jnp.mean(jnp.array(i_coords[rank])) for rank in ranks_to_test]
mean_j_coords = [jnp.mean(jnp.array(j_coords[rank])) for rank in ranks_to_test]
mean_ntk_i_coords = [mean_ntk_i_coord for rank in ranks_to_test]  # we add mean NTK I coords
mean_ntk_j_coords = [mean_ntk_j_coord for rank in ranks_to_test]  # we add mean NTK J coords

plt.plot(list(ranks_to_test), mean_i_coords, 'o-', label='Sample Mean I coordinate')
plt.plot(list(ranks_to_test), mean_j_coords, 'o-', label='Sample Mean J coordinate')
plt.plot(list(ranks_to_test), mean_ntk_i_coords, 's-', label='Mean NTK I coordinate')  # we add mean NTK I plot
plt.plot(list(ranks_to_test), mean_ntk_j_coords, 's-', label='Mean NTK J coordinate')  # we add mean NTK J plot
plt.title('I and J Coordinates vs Rank')
plt.xlabel('Rank')
plt.ylabel('Coordinate Value')
plt.legend()
plt.grid(True)
plt.show()
